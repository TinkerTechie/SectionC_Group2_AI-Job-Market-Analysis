# %% [markdown]
# # 1. Data Extraction Process
# ## Setup & Environment

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading
# Loading the raw AI Job Trends dataset from the local directory into a pandas DataFrame.

# %%
# Load the local unclean dataset
file_path = '../data/raw_dataset.csv'
df_raw = pd.read_csv(file_path)

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %% [markdown]
# ## Raw Data Assessment
# Initial inspection of the dataset to identify data quality issues, missing values, and incorrect data types before moving to the cleaning phase.

# %%
print("--- DataFrame Info ---")
df_raw.info()

print("\n--- Missing Values Check ---")
print(df_raw.isnull().sum())

print("\n--- Raw Data Head ---")
display(df_raw.head())
# Out:
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job Title                    30000 non-null  object
#  1   Industry                     30000 non-null  object
#  2   Job Status                   30000 non-null  object
#  3   AI Impact Level              30000 non-null  object
#  4   Median Salary (USD)          30000 non-null  object
#  5   Required Education           30000 non-null  object
#  6   Experience Required (Years)  30000 non-null  object
#  7   Job Openings (2024)          30000 non-null  int64
#  8   Projected Openings (2030)    30000 non-null  int64
#  9   Remote Work Ratio (%)        30000 non-null  float64
#  10  Automation Risk (%)          30000 non-null  float64
#  11  Location                     29444 non-null  object
# ...
